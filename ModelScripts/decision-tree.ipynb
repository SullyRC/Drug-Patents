# %% [markdown]
# # Decision Tree Notebook

# %%
# Non-modeling imports. Specific imports occur below.

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
# Model related imports below

# import zzz

# %%
# Import the data. Feel free to change this CSV.

df = pd.read_csv("ModelData/mbdata.csv")

# %%
df.shape[0]
# Out:
# 1643

# %%
df
# Out:
#                   Company   Price PriceStartDate  Date Added  \
# 0     GILEAD SCIENCES INC  714.37     2018-01-01  2008-08-28
# 1     GILEAD SCIENCES INC  714.37     2018-01-01  2008-08-28
# 2     GILEAD SCIENCES INC  714.37     2018-01-01  2008-08-28
# 3     GILEAD SCIENCES INC  714.37     2018-01-01  2008-08-28
# 4     GILEAD SCIENCES INC  714.37     2018-01-01  2008-08-28
# ...                   ...     ...            ...         ...
# 1638                 APIL   20.73     2018-11-09  2010-05-28
# 1639                 APIL   20.73     2018-11-09  2010-05-28
# 1640          TARO PHARMS  177.38     2018-12-01  2006-07-28
# 1641          TARO PHARMS  177.38     2018-12-01  2006-07-28
# 1642          TARO PHARMS  177.38     2018-12-01  2006-07-28
#
#       InflationAdjustedPrice         Analysis P or E  Pre2005Flag  \
# 0                 288.206982  UCadditionalnew      P            0
# 1                 288.206982        No change      P            0
# 2                 288.206982     UCadditional      P            0
# 3                 288.206982        No change      P            0
# 4                 288.206982     UCadditional      P            0
# ...                      ...              ...    ...          ...
# 1638                8.224950          P:UCnew      P            0
# 1639                8.224950            P:PED      P            0
# 1640               70.603782             P:DP      P            0
# 1641               70.603782             P:DP      P            0
# 1642               70.603782               NP      E            0
#
#       PreviousPatents LatestExpiration  MonthsUntilExpiration  PriceDelta  \
# 0                  13       2017-07-25                  106.0   -0.043701
# 1                  13       2017-07-25                  106.0   -0.043701
# 2                  13       2017-07-25                  106.0   -0.043701
# 3                  13       2017-07-25                  106.0   -0.043701
# 4                  13       2017-07-25                  106.0   -0.043701
# ...               ...              ...                    ...         ...
# 1638               59       2023-11-06                  161.0    0.000000
# 1639               59       2023-11-06                  161.0    0.000000
# 1640                0       2019-09-28                  158.0    0.000000
# 1641                0       2019-09-28                  158.0    0.000000
# 1642                0       2019-09-28                  158.0    0.000000
#
#       PercentageE
# 0        0.230769
# 1        0.230769
# 2        0.230769
# 3        0.230769
# 4        0.230769
# ...           ...
# 1638     0.000000
# 1639     0.000000
# 1640     0.000000
# 1641     0.000000
# 1642     0.000000
#
# [1643 rows x 13 columns]
